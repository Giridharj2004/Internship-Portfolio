# %%
import sqlite3
import pandas as pd

# Load dataset
df = pd.read_csv(r"C:\data analytics task 2\Cleaned_SuperStoreOrders.csv")

# Create SQLite database
conn = sqlite3.connect("global_store.db")

# Push data into SQL table
df.to_sql("super_store_sales", conn, if_exists="replace", index=False)

print("Database connected successfully!")
# Out:
# Database connected successfully!

# %%
import os
print(os.path.exists(r"C:\data analytics task 3\global_store.db"))
# Out:
# True
